# %% [markdown]
# # Chatbot Industrial Copilot - Google Colab Setup
#
# This notebook will download the Chatbot repository, install its dependencies, and run the Streamlit app. It uses `localtunnel` to give you a public URL so you can interact with the UI.

# %%
# 1. Clone the repository
# !git clone https://github.com/YOUR_GITHUB_USERNAME/industrial_chatbot_project.git
# %cd industrial_chatbot_project

# %%
# 2. Install Python dependencies
# !pip install -r requirements.txt
# !npm install -g localtunnel

# %% [markdown]
# ### Start Streamlit & Expose App
#
# When you run the cell below:
# 1. It will print an IP address (e.g., `34.123.45.67`). **Copy this IP address**.
# 2. Click the `loca.lt` link that appears.
# 3. Paste the IP address into the "Endpoint IP" field on the webpage and click "Submit".
# 4. You're in! Enter your Hugging Face API Token in the sidebar to begin.

# %%
import urllib
print("Copy this IP address:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())

# Run Streamlit in the background
get_ipython().system_raw('streamlit run app.py &>/content/logs.txt &')

# Start localtunnel
# !npx localtunnel --port 8501
